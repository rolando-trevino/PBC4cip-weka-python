# %% [markdown]
# [ ] Campo vs campo

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import pairwise_distances
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
import numpy as np
import scipy

# %%
def read_file():
    df = pd.read_csv("../../../data/processed/politicas_lema.csv")
    df['index'] = range(len(df))
    return df

def bow(df):

    df['Bag_of_words'] = ''
    columns = ['problema_lema', 'solucion_lema', 'meta_lema', 'resultado_lema']

    list_words = []
    for index, row in df.iterrows():
        words = ''
        for col in columns:
            words += words + ' ' + row[col]
        list_words.append(words)
    df['Bag_of_words'] = list_words

    return df[['index', 'titulo_caso','Bag_of_words', 'problema_lema', 'solucion_lema', 'meta_lema', 'resultado_lema', 'resumen_lema']]

def compute_vectors(df, target):
    count_binary = CountVectorizer(binary=True)
    count_binary_matrix = count_binary.fit_transform(df[target])
    
    count = CountVectorizer()
    count_matrix = count.fit_transform(df[target])

    tfidf = TfidfVectorizer()
    tfidf_matrix = tfidf.fit_transform(df[target])
    
    tfidf_uni_bi = TfidfVectorizer(ngram_range=(1,2))
    tfidf_matrix_uni_bi = tfidf.fit_transform(df[target])
    
    vect = [count_binary_matrix, count_matrix, tfidf_matrix, tfidf_matrix_uni_bi]
    
    return vect

def recommend(df, vect, title, index_var, title_list, metric = 'cosine_sim', alpha = 1, k_primeros=3):
    recommended = []
    indices = pd.Series(df[index_var])
    idx = indices[indices == title].index[0]
    
    matrix = []
    similarity_threshold = 0
    if metric == 'cosine_sim':
        matrix = cosine_similarity(vect, vect)
        matrix_arr = matrix[idx]
        matrix_arr = np.delete(matrix_arr, idx)
        similarity_threshold = np.median(matrix_arr) + alpha * matrix_arr.std()
        
    elif metric == 'euclidean':
        matrix = pairwise_distances(vect, vect, metric='euclidean')
    elif metric == 'manhattan':
        matrix = pairwise_distances(vect, vect, metric='manhattan')
    elif metric == 'jaccard':
        matrix = pairwise_distances(vect.todense(), vect.todense(), metric='jaccard')
    elif metric == 'hamming':
        matrix = pairwise_distances(vect.todense(), vect.todense(), metric='hamming')
    
    score_series = pd.Series(matrix[idx]).sort_values(ascending = False)
    score_series = score_series.drop(idx)
    
    top_10_indices = list(score_series.iloc[0:k_primeros].index)
    
    for i in top_10_indices:
        if score_series[i] >= similarity_threshold:
            recommended.append(title_list[i])
        
    return recommended, list(score_series[0:k_primeros])

def process_recommendations(df, vect_ref, metric, index_var, alpha, k_primeros):

    list_policy_index = []
    list_policy = []
    list_recommendation_index = []
    list_recommendation = []
    list_score = []
    
    for policy in df[index_var]:
        #policy = df['titulo_caso'][9]
        print(f"TOP 10 RECOMMENDATIONS FOR POLICY: [{str(policy[:80])}...]:")
        i = 1
        for recommendation, score in zip(*recommend(df, vect_ref, policy, index_var, list(df[index_var]), metric, alpha, k_primeros)):
            list_policy_index.append(df.loc[df['titulo_caso'] == policy]['index'].values[0])
            list_policy.append(policy)
            list_recommendation_index.append(df.loc[df['titulo_caso'] == recommendation]['index'].values[0])
            list_recommendation.append(recommendation)
            list_score.append(score)
            print(f"\t[{i:<2}] Title: {recommendation[:30]:<30}... Similarity Score: {str(round(score, 8)):<12}")
            i = i+1
        print("\n")
        
    rec_df = pd.DataFrame()
    rec_df['policy_index'] = list_policy_index
    rec_df['policy'] = list_policy
    rec_df['recommendation_index'] = list_recommendation_index
    rec_df['recommendation'] = list_recommendation
    rec_df['score'] = list_score
    
    return rec_df

# %% [markdown]
# <p></p>
# <div>
# <img src="quarts.png" width="500"/>
# </div>

# %%
df = read_file()
df = bow(df)

target_list = ['problema_lema', 'solucion_lema', 'meta_lema', 'resultado_lema', 'Bag_of_words', 'resumen_lema']
target = target_list[5]
vect = compute_vectors(df, target)

vect_ref = vect[3]
metric = 'cosine_sim'
index_var = 'titulo_caso'
alpha = 0.6745
rec_df = process_recommendations(df, vect_ref, metric, index_var, alpha, k_primeros=3)
rec_df.to_csv(f"../../../data/model_ready/recommendations_{target[:-5]}.csv", index=False, encoding='utf8')
# Out:
# TOP 10 RECOMMENDATIONS FOR POLICY: [Juan Manuel Carreras anuncia paquete por más de 3200 mdp para SLP ante contingen...]:
# 	[1 ] Title: El Programa de Apoyo Económico... Similarity Score: 0.18467429
# 	[2 ] Title: Coronavirus: Senado aprueba pr... Similarity Score: 0.13240626
# 	[3 ] Title: Programa de Seguridad Alimenta... Similarity Score: 0.10484993
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Uber Eats apoya a las mipymes de Aguascalientes...]:
# 	[1 ] Title: https://www.ocregister.com/202... Similarity Score: 0.17746169
# 	[2 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.15131481
# 	[3 ] Title: Jalisco ordena el cierre de pl... Similarity Score: 0.10192467
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Control and Prevention for Solid Waste Management Workers and Employers...]:
# 	[1 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.29111844
# 	[2 ] Title: Intensifica Salum medidas cont... Similarity Score: 0.14650888
# 	[3 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.09613811
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Programa de Seguridad Alimentaria de Sonora...]:
# 	[1 ] Title: Apoya Municipio a pequeños com... Similarity Score: 0.14462765
# 	[2 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.10904521
# 	[3 ] Title: Juan Manuel Carreras anuncia p... Similarity Score: 0.10484993
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [https://www.ocregister.com/2020/04/02/coronavirus-help-onwardca-created-to-help-...]:
# 	[1 ] Title: Uber Eats apoya a las mipymes ... Similarity Score: 0.17746169
# 	[2 ] Title: Se realiza la fumigación en ár... Similarity Score: 0.11261026
# 	[3 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.09399355
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Ante afectaciones económicas por COVID-19 juez ordena incentivos fiscales a desp...]:
# 	[1 ] Title: El Programa de Apoyo Económico... Similarity Score: 0.1387296
# 	[2 ] Title: Colima restringirá accesos par... Similarity Score: 0.07297218
# 	[3 ] Title: Juan Manuel Carreras anuncia p... Similarity Score: 0.06599448
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [El Programa de Apoyo Económico ante la Contingencia por COVID-19...]:
# 	[1 ] Title: Juan Manuel Carreras anuncia p... Similarity Score: 0.18467429
# 	[2 ] Title: Ante afectaciones económicas p... Similarity Score: 0.1387296
# 	[3 ] Title: A public data lake for analysi... Similarity Score: 0.12515297
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Amid Ongoing COVID-19 Pandemic Governor Cuomo Announces New York State is Rampin...]:
# 	[1 ] Title: Se realiza la fumigación en ár... Similarity Score: 0.13759492
# 	[2 ] Title: Cabildo aprueba medidas extrao... Similarity Score: 0.12787642
# 	[3 ] Title: El Programa de Apoyo Económico... Similarity Score: 0.10306392
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Governor Newsom Announces New Program to Provide Front-Line Health Care Workers ...]:
# 	[1 ] Title: Hospital Digital capacita a má... Similarity Score: 0.11470664
# 	[2 ] Title: Intensifica Salum medidas cont... Similarity Score: 0.05967232
# 	[3 ] Title: Amid Ongoing COVID-19 Pandemic... Similarity Score: 0.05920607
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Colima restringirá accesos para evitar propagación de Covid-19...]:
# 	[1 ] Title: Así es Colima el estado con me... Similarity Score: 0.29720955
# 	[2 ] Title: Se realiza la fumigación en ár... Similarity Score: 0.18863725
# 	[3 ] Title: Cabildo aprueba medidas extrao... Similarity Score: 0.14621478
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Se realiza la fumigación en áreas del Cuartel General de la Policía Estatal de O...]:
# 	[1 ] Title: Colima restringirá accesos par... Similarity Score: 0.18863725
# 	[2 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.16291686
# 	[3 ] Title: Amid Ongoing COVID-19 Pandemic... Similarity Score: 0.13759492
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Cabildo aprueba medidas extraordinarias por COVID-19...]:
# 	[1 ] Title: Jalisco ordena el cierre de pl... Similarity Score: 0.15866704
# 	[2 ] Title: Instalaran filtros sanitarios ... Similarity Score: 0.14971876
# 	[3 ] Title: Colima restringirá accesos par... Similarity Score: 0.14621478
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Impact of COVID-19 on residents of Canada’s long-term care homes – ongoing chall...]:
# 	[1 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.08422187
# 	[2 ] Title: “Quédate en casa” Salum anunci... Similarity Score: 0.06753771
# 	[3 ] Title: Instalaran filtros sanitarios ... Similarity Score: 0.06064671
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Letter from Italy: First practical indications for radiation therapy departments...]:
# 	[1 ] Title: Hospital Digital capacita a má... Similarity Score: 0.11447474
# 	[2 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.08010881
# 	[3 ] Title: Instalaran filtros sanitarios ... Similarity Score: 0.07588183
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Hospital Digital capacita a más de 28 mil profesionales en cuidado de pacientes ...]:
# 	[1 ] Title: Governor Newsom Announces New ... Similarity Score: 0.11470664
# 	[2 ] Title: Letter from Italy: First pract... Similarity Score: 0.11447474
# 	[3 ] Title: Intensifica Salum medidas cont... Similarity Score: 0.09243439
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [APORTA GOBIERNO DE BJ MÓDULO DE DIAGNÓSTICO Y ATENCIÓN DE COVID-19 EN APOYO A LA...]:
# 	[1 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.09220087
# 	[2 ] Title: Hospital Digital capacita a má... Similarity Score: 0.08443625
# 	[3 ] Title: Coronavirus: gobierno anuncia ... Similarity Score: 0.06817999
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Intensifica Salum medidas contra el COVID-19...]:
# 	[1 ] Title: Control and Prevention for Sol... Similarity Score: 0.14650888
# 	[2 ] Title: Instalaran filtros sanitarios ... Similarity Score: 0.13206054
# 	[3 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.12771354
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [A public data lake for analysis of COVID-19 data...]:
# 	[1 ] Title: Making things open is making t... Similarity Score: 0.17272815
# 	[2 ] Title: El Programa de Apoyo Económico... Similarity Score: 0.12515297
# 	[3 ] Title: Coronavirus: el Senado lo apru... Similarity Score: 0.06888482
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Aprueba Cabildo de Oaxaca de Juárez medidas adicionales para evitar contagios de...]:
# 	[1 ] Title: Se realiza la fumigación en ár... Similarity Score: 0.16291686
# 	[2 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.1599179
# 	[3 ] Title: Intensifica Salum medidas cont... Similarity Score: 0.12771354
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Así es Colima el estado con menos casos y defunciones por COVID-19...]:
# 	[1 ] Title: Colima restringirá accesos par... Similarity Score: 0.29720955
# 	[2 ] Title: COMUNICA Y HACE GOBIERNO MARA ... Similarity Score: 0.1478537
# 	[3 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.10347021
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Making things open is making things better...]:
# 	[1 ] Title: A public data lake for analysi... Similarity Score: 0.17272815
# 	[2 ] Title: Coronavirus: gobierno anuncia ... Similarity Score: 0.12992564
# 	[3 ] Title: https://www.ocregister.com/202... Similarity Score: 0.08955442
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Apoya Municipio a pequeños comerciantes...]:
# 	[1 ] Title: Programa de Seguridad Alimenta... Similarity Score: 0.14462765
# 	[2 ] Title: Uber Eats apoya a las mipymes ... Similarity Score: 0.08998804
# 	[3 ] Title: Juan Manuel Carreras anuncia p... Similarity Score: 0.0889209
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [“Quédate en casa” Salum anuncia medidas drásticas para contener contingencia por...]:
# 	[1 ] Title: Coronavirus: gobierno anuncia ... Similarity Score: 0.13822064
# 	[2 ] Title: Cabildo aprueba medidas extrao... Similarity Score: 0.0861169
# 	[3 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.06936845
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Jalisco ordena el cierre de playas y balnearios por la contingencia del coronavi...]:
# 	[1 ] Title: Instalaran filtros sanitarios ... Similarity Score: 0.22645418
# 	[2 ] Title: Cabildo aprueba medidas extrao... Similarity Score: 0.15866704
# 	[3 ] Title: Uber Eats apoya a las mipymes ... Similarity Score: 0.10192467
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [COMUNICA Y HACE GOBIERNO MARA EN TRANSMISIONES DIARIAS...]:
# 	[1 ] Title: Así es Colima el estado con me... Similarity Score: 0.1478537
# 	[2 ] Title: Cabildo aprueba medidas extrao... Similarity Score: 0.12349897
# 	[3 ] Title: Colima restringirá accesos par... Similarity Score: 0.10485404
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Coronavirus in South Korea: How trace test and treat may be saving lives...]:
# 	[1 ] Title: Planeación de Preparación del ... Similarity Score: 0.09324294
# 	[2 ] Title: Hospital Digital capacita a má... Similarity Score: 0.08945755
# 	[3 ] Title: Letter from Italy: First pract... Similarity Score: 0.05774505
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Planeación de Preparación del Sistema de Salud Pública...]:
# 	[1 ] Title: Coronavirus in South Korea: Ho... Similarity Score: 0.09324294
# 	[2 ] Title: Juan Manuel Carreras anuncia p... Similarity Score: 0.0799182
# 	[3 ] Title: Amid Ongoing COVID-19 Pandemic... Similarity Score: 0.05526978
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Instalaran filtros sanitarios en carreteras de jalisco para evitar propagación d...]:
# 	[1 ] Title: Jalisco ordena el cierre de pl... Similarity Score: 0.22645418
# 	[2 ] Title: Cabildo aprueba medidas extrao... Similarity Score: 0.14971876
# 	[3 ] Title: Intensifica Salum medidas cont... Similarity Score: 0.13206054
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [La Cruz Roja Italiana lanza recaudación de fondos en Bitcoin para combatir el Co...]:
# 	[1 ] Title: El Programa de Apoyo Económico... Similarity Score: 0.08098878
# 	[2 ] Title: Juan Manuel Carreras anuncia p... Similarity Score: 0.05670734
# 	[3 ] Title: https://www.ocregister.com/202... Similarity Score: 0.04784798
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [¿Qué actividades se han suspendido? ...]:
# 	[1 ] Title: Control and Prevention for Sol... Similarity Score: 0.29111844
# 	[2 ] Title: Coronavirus: gobierno anuncia ... Similarity Score: 0.21857653
# 	[3 ] Title: Aprueba Cabildo de Oaxaca de J... Similarity Score: 0.1599179
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Coronavirus: el Senado lo aprueba se publica Gaceta Oficial y entra en vigencia ...]:
# 	[1 ] Title: Intensifica Salum medidas cont... Similarity Score: 0.11422071
# 	[2 ] Title: A public data lake for analysi... Similarity Score: 0.06888482
# 	[3 ] Title: El Programa de Apoyo Económico... Similarity Score: 0.05615343
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Coronavirus: gobierno da 3 meses para depositar FGTS anticipa 13 del INSS y refu...]:
# 	[1 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.13663288
# 	[2 ] Title: Coronavirus: Bolsonaro emite r... Similarity Score: 0.0984324
# 	[3 ] Title: El Programa de Apoyo Económico... Similarity Score: 0.09300448
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Coronavirus: Bolsonaro emite reglamentación que enmienda reglas laborales en med...]:
# 	[1 ] Title: La reducción de la carga de tr... Similarity Score: 0.19660691
# 	[2 ] Title: Coronavirus: gobierno da 3 mes... Similarity Score: 0.0984324
# 	[3 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.09478085
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Coronavirus: Senado aprueba proyecto de ley que entrega R $ 600 mensuales a trab...]:
# 	[1 ] Title: Coronavirus: gobierno anuncia ... Similarity Score: 0.30006179
# 	[2 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.13463504
# 	[3 ] Title: Juan Manuel Carreras anuncia p... Similarity Score: 0.13240626
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [La reducción de la carga de trabajo con reducción de salario puede ser de hasta ...]:
# 	[1 ] Title: Coronavirus: Bolsonaro emite r... Similarity Score: 0.19660691
# 	[2 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.10719935
# 	[3 ] Title: Coronavirus: gobierno anuncia ... Similarity Score: 0.09257289
#
#
# TOP 10 RECOMMENDATIONS FOR POLICY: [Coronavirus: gobierno anuncia paquete de R $ 858 mil millones para estados y mun...]:
# 	[1 ] Title: Coronavirus: Senado aprueba pr... Similarity Score: 0.30006179
# 	[2 ] Title: ¿Qué actividades se han suspen... Similarity Score: 0.21857653
# 	[3 ] Title: “Quédate en casa” Salum anunci... Similarity Score: 0.13822064
